# %%
print("Hello World")
# Out:
# Hello World

# %%
# !pip install pandas numpy matplotlib seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in C:\Users\amrut\AppData\Roaming\Python\Python313\site-packages (2.3.3)
# Requirement already satisfied: numpy in C:\Users\amrut\AppData\Roaming\Python\Python313\site-packages (2.4.1)
# Requirement already satisfied: matplotlib in C:\Users\amrut\AppData\Roaming\Python\Python313\site-packages (3.10.8)
# Requirement already satisfied: seaborn in C:\Users\amrut\AppData\Roaming\Python\Python313\site-packages (0.13.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\amrut\AppData\Roaming\Python\Python313\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in C:\Users\amrut\AppData\Roaming\Python\Python313\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in C:\Users\amrut\AppData\Roaming\Python\Python313\site-packages (from pandas) (2025.3)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\amrut\AppData\Roaming\Python\Python313\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\amrut\AppData\Roaming\Python\Python313\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\amrut\AppData\Roaming\Python\Python313\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\amrut\AppData\Roaming\Python\Python313\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in C:\Users\amrut\AppData\Roaming\Python\Python313\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in C:\Users\amrut\AppData\Roaming\Python\Python313\site-packages (from matplotlib) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\amrut\AppData\Roaming\Python\Python313\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: six>=1.5 in C:\Users\amrut\AppData\Roaming\Python\Python313\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

print("All libraries imported successfully!")
# Out:
# All libraries imported successfully!
